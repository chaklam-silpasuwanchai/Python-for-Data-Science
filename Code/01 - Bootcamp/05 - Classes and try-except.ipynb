# %% [markdown]
# # Programming for Data Science and Artificial Intelligence

# %% [markdown]
# ### Classes

# %% [markdown]
# Classes are the key features of object-oriented programming. A class is a structure for representing an object and the operations that can be performed on the object.
#
# In Python a class can contain *attributes* (variables) and *methods* (functions).
#
# A class is defined almost like a function, but using the `class` keyword, and the class definition usually contains a number of class method definitions (a function in a class).
#
# * **Each class method should have an argument `self` as it first argument. This object is a self-reference.**
#
# * Some class method names have special meaning, for example:
#
#     * `__init__`: The name of the method that is invoked when the object is first created.
#     * `__str__` : A method that is invoked when a simple string representation of the class is needed, as for example when printed.
#     * There are many more, see http://docs.python.org/2/reference/datamodel.html#special-method-names
#     * https://www.youtube.com/watch?v=rJzjDszODTI

# %%
class Point:
    """
    Simple class for representing a point in a Cartesian coordinate system.
    """
    
    def __init__(self, x, y):
        """
        Create a new Point at x, y.
        """
        self.x = x
        self.y = y
        
    def translate(self, dx, dy):
        """
        Translate the point by dx and dy in the x and y direction.
        """
        self.x += dx
        self.y += dy
        
    def __str__(self):
        return("Point at [%f, %f]" % (self.x, self.y))

# %% [markdown]
# To create a new instance of a class:

# %%
p1 = Point(0, 0) # this will invoke the __init__ method in the Point class

print("1: ", p1)         # this will invoke the __str__ method
# Out:
# 1:  Point at [0.000000, 0.000000]

# %% [markdown]
# To invoke a class method in the class instance `p`:

# %%
p2 = Point(1, 1)

p1.translate(0.25, 1.5)

print("1: ", p1)
print("2: ", p2)
# Out:
# 1:  Point at [0.250000, 1.500000]
# 2:  Point at [1.000000, 1.000000]

# %% [markdown]
# Another example

# %%
class Circle:
    pi = 3.14

    # Circle gets instantiated with a radius (default is 1)
    def __init__(self, radius=1):
        self.radius = radius 
        self.area = radius * radius * Circle.pi

    # Method for resetting Radius
    def setRadius(self, new_radius):
        self.radius = new_radius
        self.area = new_radius * new_radius * self.pi

    # Method for getting Circumference
    def getCircumference(self):
        return self.radius * self.pi * 2


c = Circle()

print('1: Radius is: ',c.radius)
print('2: Area is: ',c.area)
print('3: Circumference is: ',c.getCircumference())
# Out:
# 1: Radius is:  1
# 2: Area is:  3.14
# 3: Circumference is:  6.28

# %% [markdown]
# ### === Task 6 ===
#
# 1. Create a class called `class rectangle()`. This class includes the following functions:
#
# - `__init__()` where height and width of your rectangle are initiated.
# - `setHeight()` and `setWidth()` which allow you to change height and width of your rectangle.
# - `getArea()` where the area of your rectangle is returned.

# %% [markdown]
# ### Try/Except
# Every programming language has a form of Error handling.
#
# [link](https://www.section.io/engineering-education/exceptions-and-error/)
#
# What is Error?
#
# Here are they.

# %% [markdown]
# #### Error

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /root/projects/Lectures/01-Bootcamp/05 - Classes and try-except.ipynb Cell 13 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000013vscode-remote?line=0'>1</a> a
#
# NameError: name 'a' is not defined

# %%
1/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /root/projects/Lectures/01-Bootcamp/05 - Classes and try-except.ipynb Cell 14 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000014vscode-remote?line=0'>1</a> 1/0
#
# ZeroDivisionError: division by zero

# %%
while True print('a')
# Out:
#   Input In [4]
#     while True print('a')
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# Look closer to the Error. It consists of two sections. (1) Traceback and (2) Message
#
# Imagine a code is executing. It executes from top to bottom. If thing runs smoothly, that is happy ending. However, if computer/interpreter facing an unexpected event, what should it do?
#
# Imagine you are asked by your mom to go shopping for 1 Kg of tomatoes. Your mom gives you 100 baht to do so. At the time you have arrived the store, the 1 Kg of tomatoes is actually costing 200 baht. Oh no, it does not go as expected. What should you do? (1) you could assume that a 0.5 Kg should be fine and risk that your mom might get upset later when she knows you do not deliver what she wants. Or (2) you could call your mom and tell her what went wrong in the process.
#
# The second option is the same as Error message. The computer wants to tell you something went wrong (Error message) and try to explain what happened (Traceback).
#
# The above errors I showed you are easy to fix. Once fixed, it most likely never occur again. So did we handle errors yet? Yes and no.
#
# Before we understand why, let's see where does these errors come from.

# %%
raise ZeroDivisionError("Hey, you can not divide anything with 0. FIX IT!!!")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /root/projects/Lectures/01-Bootcamp/05 - Classes and try-except.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000019vscode-remote?line=0'>1</a> raise ZeroDivisionError("Hey, you can not divide anything with 0. FIX IT!!!")
#
# ZeroDivisionError: Hey, you can not divide anything with 0. FIX IT!!!

# %% [markdown]
# At some point of the execution, someone writes this, `raise`. This follow by the type of error with error message is causing the red text. This `raise` will stop all the execution and report immediately.

# %%
print('My mom told me to go shopping')
print('My mom gave me 100 baht')
print('The tomatoes are 200 baht')
raise ValueError("I don't have enough money")
print('I got the tomatoes')
print('Happy ending')
# Out:
# My mom told me to go shopping
# My mom gave me 100 baht
# The tomatoes are 200 baht
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /root/projects/Lectures/01-Bootcamp/05 - Classes and try-except.ipynb Cell 20 in <cell line: 4>()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000021vscode-remote?line=1'>2</a> print('My mom gave me 100 baht')
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000021vscode-remote?line=2'>3</a> print('The tomatoes are 200 baht')
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000021vscode-remote?line=3'>4</a> raise ValueError("I don't have enough money")
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000021vscode-remote?line=4'>5</a> print('I got the tomatoes')
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000021vscode-remote?line=5'>6</a> print('Happy ending')
#
# ValueError: I don't have enough money

# %% [markdown]
# Facing an error at development phase is fine. It does not affect anything but you, the coder. However, when error happens, the program stops running. This mean every time something goes wrong, the computer will seek your attention.
#
# To prevent the code from stop running, we use Try/Except

# %%
print('My mom told me to go shopping')
print('My mom gave me 100 baht')
try:
    print('The tomatoes are 200 baht')
    raise ValueError("I don't have enough money")
except ValueError as e:
    print('call my mom for more money')

print('I got the tomatoes')
print('Happy ending')
# Out:
# My mom told me to go shopping
# My mom gave me 100 baht
# The tomatoes are 200 baht
# call my mom for more money
# I got the tomatoes
# Happy ending

# %% [markdown]
# In the above scenario, I use try/except to fix the error during run time. Sure, you can write if/else to check whether you have enough money before buying tomatoes.
#
# Here is the equivalent (sort of) piece of code.

# %%
print('My mom told me to go shopping')
print('My mom gave me 100 baht')
wallet = 100
print('The tomatoes are 200 baht')
tomatoes = 200
if(tomatoes > wallet):
    print('call my mom for more money')
print('I got the tomatoes')
print('Happy ending')
# Out:
# My mom told me to go shopping
# My mom gave me 100 baht
# The tomatoes are 200 baht
# call my mom for more money
# I got the tomatoes
# Happy ending

# %% [markdown]
# You can always use if/else to pre-handle the error and prevent it from happening. Which is doable. However, to me there are drawbacks.
#
# 1. Your code will have a hundred of if/else which reduce the readability of your code. When you see a section of if/else, is it a part of business logic or error handling.
# 2. You will never prevent every possible errors.
#
# What if there is no tomato? In the try/except you can except *any* error
#
# Before that, I will encapsulate the purchasing function for the code to look sensible.

# %%
def buy_tomato(buyer_wallet: int, tomatoes_cost: int) -> bool:
    if(tomatoes_cost == None):
        # This mean there is not tomatoes
        raise RuntimeError("There is no tomatoes")
    if(tomatoes_cost > buyer_wallet):
        # If the tomatoes is more expensive than buyer can effort
        raise ValueError("I don't have enough money")
    
    return True

# %%
print('My mom told me to go shopping')
print('My mom gave me 100 baht')
wallet = 100
print('There is no tomatoes')
tomatoes = None
try:
    buy_tomato(buyer_wallet=wallet, tomatoes_cost=tomatoes)
except ValueError as e:
    print('call my mom for more money')
    print('I got the tomatoes')
except Exception as e:
    print(e)

print('Happy ending')
# Out:
# My mom told me to go shopping
# My mom gave me 100 baht
# There is no tomatoes
# There is no tomatoes
# Happy ending

# %% [markdown]
# The `Exception` is the root of all exception/error in Python.
#
# ![alt](https://www.section.io/engineering-education/exceptions-and-error/exception_hierarchy.png)

# %%
print('My mom told me to go shopping')
print('My mom gave me 100 baht')
wallet = 100
print('There is no tomatoes')
tomatoes = 200
try:
    buy_tomato(buyer_wallet=wallet, tomatoes_cost=tomatoes)
except Exception as e: # Here I switch the order of the `expect`. and although the actual error is ValueError, this except will handle first becuse ValueError is a kind of Exception.
    print(e)
except ValueError as e:
    print('call my mom for more money')
    print('I got the tomatoes')

print('Happy ending')
# Out:
# My mom told me to go shopping
# My mom gave me 100 baht
# There is no tomatoes
# I don't have enough money
# Happy ending

# %%
print('My mom told me to go shopping')
print('My mom gave me 100 baht')
wallet = 100
print('There is no tomatoes')
tomatoes = 200
try:
    buy_tomato(buyer_wallet=wallet, tomatoes_cost=tomatoes)
except ValueError as e: # Switch back to prove
    print('call my mom for more money')
    print('I got the tomatoes')
except Exception as e:
    print(e)

print('Happy ending')
# Out:
# My mom told me to go shopping
# My mom gave me 100 baht
# There is no tomatoes
# call my mom for more money
# I got the tomotes
# Happy ending

# %% [markdown]
# In some events, there might be an action that is required no matter what. For instance, if you open a file for read and write then the file have to be close at the end no matter what.
#
# In this shopping scenario, you have to go home with or without the tomatoes. To do that, we use `finally`.

# %%
print('My mom told me to go shopping')
print('My mom gave me 100 baht')
wallet = 100
print('There is no tomatoes')
tomatoes = 200
try:
    buy_tomato(buyer_wallet=wallet, tomatoes_cost=tomatoes)
except ValueError as e:
    print('call my mom for more money')
    print('I got the tomatoes')
except Exception as e:
    print(e)
finally:
    print('I go home')
    
print('Happy ending')
# Out:
# My mom told me to go shopping
# My mom gave me 100 baht
# There is no tomatoes
# call my mom for more money
# I got the tomotes
# I go home
# Happy ending

# %% [markdown]
# Now, you ask. It is always 'happy ending' this mean we don't need `finally` to ensure code execution, right?
#
# Then, what happen if you call your mon, and she says no money for you.

# %%
print('My mom told me to go shopping')
print('My mom gave me 100 baht')
wallet = 100
print('There is no tomatoes')
tomatoes = 200
try:
    buy_tomato(buyer_wallet=wallet, tomatoes_cost=tomatoes)
except ValueError as e:
    print('call my mom for more money')
    raise RuntimeError("No money for you")
    print('I got the tomatoes')
except Exception as e:
    print(e)
finally:
    print('I go home')
    
print('Happy ending')
# Out:
# My mom told me to go shopping
# My mom gave me 100 baht
# There is no tomatoes
# call my mom for more money
# I go home
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /root/projects/Lectures/01-Bootcamp/05 - Classes and try-except.ipynb Cell 34 in <cell line: 6>()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=5'>6</a> try:
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=6'>7</a>     buy_tomato(buyer_wallet=wallet, tomatoes_cost=tomatoes)
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=7'>8</a> except ValueError as e: # Switch back to prove
#
# /root/projects/Lectures/01-Bootcamp/05 - Classes and try-except.ipynb Cell 34 in buy_tomato(buyer_wallet, tomatoes_cost)
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=4'>5</a> if(tomatoes_cost > buyer_wallet):
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=5'>6</a>     # If the tomatoes is more expensive than buyer can afford
# ----> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=6'>7</a>     raise ValueError("I don't have enough money")
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=8'>9</a> return True
#
# ValueError: I don't have enough money
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# /root/projects/Lectures/01-Bootcamp/05 - Classes and try-except.ipynb Cell 34 in <cell line: 6>()
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=7'>8</a> except ValueError as e: # Switch back to prove
#       <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=8'>9</a>     print('call my mom for more money')
# ---> <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=9'>10</a>     raise RuntimeError("No money for you")
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=10'>11</a>     print('I got the tomotes')
#      <a href='vscode-notebook-cell://attached-container%2B7b22636f6e7461696e65724e616d65223a222f707974686f6e2d666f722d646174612d736369656e63652d707974686f6e2d31227d/root/projects/Lectures/01-Bootcamp/05%20-%20Classes%20and%20try-except.ipynb#ch0000036vscode-remote?line=11'>12</a> except Exception as e:
#
# RuntimeError: No money for you

# %% [markdown]
# You see, this is not a happy ending because you don't get the money. Therefore, no tomato.
#
# But no matter what happen, you go home.
#
# Lastly, `else` is used when thing goes smoothly

# %%
print('My mom told me to go shopping')
print('My mom gave me 100 baht')
wallet = 100
print('There is no tomatoes')
tomatoes = 100
try:
    buy_tomato(buyer_wallet=wallet, tomatoes_cost=tomatoes)
except ValueError as e:
    print('call my mom for more money')
    raise RuntimeError("No money for you")
except Exception as e:
    print(e)
else:
    # you got the tomatoes only when you have enough money
    print('I got the tomatoes')
finally:
    print('I go home')
    
print('Happy ending')
# Out:
# My mom told me to go shopping
# My mom gave me 100 baht
# There is no tomatoes
# I got the tomatoes
# I go home
# Happy ending

# %% [markdown]
# Honestly, I just know there is `else` in `try/except` of Python, and I could not think of how does it really make sense. But then I remember what does `try/except` help for me.
#
# `try/except` helps me to read and understand what line does what. If you know all the convention then you don't really need to read my comment. There is less time to figure out what is happening here.
#
# In this sense, `try` block is used when this code or section of codes is likely to have an error. `except _ as e` is what the coder knew at the time of writing the code. `except` is usually used for logging information in the production. `finally` is what needed to run no matter what. And, `else` is when try is success and should not have any error anymore or if it does, write another `try/except`.

# %% [markdown]
# ### === Task 6 ===
#
# 1. Write a function to compute 5/0 and use `try/except` to catch the exceptions.

# %% [markdown]
# # Happy Ending

# %% [markdown]
# Finally, it does not mean that without function, class, and try-except, you can not write a workable code. Because, in the end, what user sees is the output not the code, if the code suck, but it works, it works.
#
# But will your project scalable? Will it be easy to debug? Will your teammate be happy to fix your code?
#
# Writing a good code is not a must but should. Just like you don't need to be polite, but you should.
