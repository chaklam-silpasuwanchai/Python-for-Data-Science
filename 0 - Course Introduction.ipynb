# %% [markdown]
# # Programming for Data Science and Artificial Intelligence
#
# ## 0 Course Introduction

# %% [markdown]
# * My name is Chaklam.  Born Hong Kong.  Research Interests on Neurosciene and Machine Learning.  Welcome you all!  This course will be fun and super tough!
#
# * All materials can be found on my **Github - https://github.com/chaklam-silpasuwanchai/**.  If you forget, you can also get the link from http://chaklam.com
#
# * I am sitting in either room **101** or **203** most of the time.  Please send emails to my calendar - chaklam@ait.asia for appointment
#
# * Room 203 also has many machine learning books I used for this class.  You are not allowed to take them away - but you are certainly welcomed to read them at my lab mini library.
#
# * For online folks, you can always schedule a zoom meeting with me by sending me emails.
#
# * Introducing our TA, Ms. Pranisaa (Beau) - st121720@ait.asia.  She will be in charge of
#   - Google classroom (code: will be provided by Beau)
#   - Checking assignments
#   - Uploading our lecture video to some repository
#   - Organizing quiz
#   - Troubleshoot any of your problems during class (but please be gentle to him!)
#
# ### Setting up your Python and Jupyter
#
# * I use **python3** as interpreter.
#
# * We will be using a lot of modules that may not be pre-built in python, so I assume you know how to use pip to install missing modules.   I also assume you use linux systems since I have no experience in Windows :)  Read Lab 0 if you haven't.
#
# * Highly recommend to use **venv** to setup your python environment, before installing python modules.  If you do not know how and what is venv, read this.  https://docs.python.org/3/library/venv.  Docker is welcomed as well.
#
# * Sometimes, it will take like several hours (like 3 to 4 hours) to run your model.  CSIM has some resources which you can use to help your model train faster.  One is the puffer system.  You can access it using https://puffer.cs.ait.ac.th  (in CSIM), which got four 2080Tis, 64GBs Ram, and very powerful CPU (I don't remember the series).  You must use your CSIM account to access and has been allocated a certain space amount.  Note that ~jovyan/ is all temporary, going away when the user's server is shut down. ~jovyan/work is persistent.   All notebooks are automatically stored in /work so do not worry your file will be lost.   The current server is a work-in-progress so make sure you backup!  There are also some PCs you can use at CSIM lab which has one NVIDIA 2060 super, i7, so that's plenty for you to run your model as well.
#
# ### Pre-requisites / Expectations
#
# * This course aims for **technical, research oriented** audience who would like to develop **fundamental** skills needed to link math, data sicence, and python seemlessly together.  Afterall, this is a Master degree course.
#
# * Thus, this course shall focus on **coding from scratch**. This has several reasons/benefits:
#     - a) You can keep up with the recent trend by reading papers by yourself and then write them yourself in python,
#     - b) It is much easier to make understanding in scratch first, then sklearn
#     - c) There are too many youtube videos on sklearn and mostly can be self-learned, not to mention that Rapidminer and many other software can do it.  I would like to focus more on things that are difficult to self-learn.
#     - d) There are other courses such as **Business Intelligence** that aims more toward **business** audience.
#
# * **Math, especially knowledge in linear algebra, differential calculus, and gaussian statistics are required**.  I assume that you know most of them.  This will be a very difficult course without any mathematical backgrounds. For your own deeper study, I recommend the followings:
#     - Linear Algebra short recap - https://www.cs.cmu.edu/~zkolter/course/15-884/linalg-review.pdf;  Recommended book - http://linear.axler.net; Recommended playlist (Prof. Gilbert Strang) - https://www.youtube.com/watch?v=7UJ4CFRGd-U&list=PLE7DDD91010BC51F8
#     - Stats - http://greenteapress.com/thinkstats/ (free!)
#
# * **Python** is assumed to be known before you enroll this course.  I shall give you a crash course, but for those without any prior experience in Python, it will be extremely difficult.
#
# * I have prepare some tutorials you must self-study with the beginning "0". Please look through them as it will be helpful to understand the course.
#
# * This course is best taken together with **Machine Learning with Prof. Matthew Dailey**, where you can study the full derivation of formulas.  We shared a lot of similarities such as regression, and classification, but with a stronger focus on the integration between mathematics and python programming.
#
# * Very practical course.  **Intermediate level**. Could be **extremely** difficult for those without any programming experience.  Requires **huge huge amount of self-study hours**, especially if you are weak in programming/math.
#
# * Always read before you come to the class.  It will be very helpful to your learning.
#
#
# ### What kind of *ouptput* students this course wants to produce
#
# I have actually high expectations of myself to develop strong mathematical and programming skills in students.  Here are what I expect the students who finish my course will look like:
#
# - Able to **code python fluently**, with good object-oriented (OO) and software engineering (SE) principles.  In a sense, students should be able to write class in a "clean", "efficient", and "pythonic" way.
#
# - Able to **self-study** advanced python stuffs in the future by increasing literacy in reading APIs, documentations, etc.  Thus, I encourage students to read APIs frequently, instead of just copying answers from StackOverflow.
#
# - Able to **read mathematics** on any given research papers without too much difficulty.  Thus I shall cover machine learning algorithms from the perspectives of mathematics, as a mean for you to get acquainted with mathematics.  Also, we shall ask you to read LOTs of papers in your project, to get you acquainted with maths.
#
# - Able to **translate those mathematical knowledge to python programming**.  Thus, our class will focus on coding from scratch, rather than using library such as sklearn or pytorch but sklearn and pyTorch will be taught as well but will not be the focus.
#
# - Able to understand what are some useful machine learning algorithms, how to implement them, and most importantly, *when* or *when NOT* to use them.  Thus I shall regularly compare and contrast different algorithms, i.e., weakness and strengths.
#
# - Able to **self-explore, self-learn beyond the course materials, and link all the knowledge** you have, and combined with your own unique background (e.g., economics, medicine, finance, retail) to solve a particular data problem.  More importantly, able to *judge whether a problem is worth solving*.   Thus I shall hope that project is a good starting point.
#
# ### Resources
#
# * Reference books:
#     - [GERON] Geron, A. **Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems**, 2019 (2nd edition) (https://github.com/ageron/handson-ml2)
#     - [VANDER] VanderPlas, J. **Python Data Science Handbook: Essential Tools for Working with Data**, 2016 (1st edition) (https://jakevdp.github.io/PythonDataScienceHandbook/)
#     - [HASTIE] Hastie, T., Tibshirani, R., and Friedman, J. **The Elements of Statistical Learning: Data Mining, Inference, and Prediction**, 2016 (2nd edition) (https://web.stanford.edu/~hastie/Papers/ESLII.pdf_)
#     - [WEIDMAN] Weidman, S. **Deep Learning from Scratch: Building with Python from First Principles**, 2019 (1st edition) (https://github.com/SethHWeidman/DLFS_code)
#     - [CHARU] Charu, C. **Neural Networks and Deep Learning: A Textbook**, 2018 (1st edition)
#     - [Deisenroth] Deisenroth, M.P., Faisal A.A., Ong, C.S., **Mathematics for Machine Learning**, 2020 (1st edition) (https://mml-book.github.io/book/mml-book.pdf)
#
# * Online resources:
#     - Python tutorials available online: https://docs.python.org/3/tutorial/
#     - Jupyter notebook tutorials available online: https://ipython.org/documentation.html
#     - Numpy tutorials available online:https://numpy.org/doc/stable/
#     - Pandas tutorials available online: https://pandas.pydata.org/docs/
#     - Nltk tutorials available online: https://www.nltk.org
#     - Matplotlib tutorials available online: https://matplotlib.org/contents.html
#     - Scikit-learn tutorials available online: https://scikit-learn.org/stable/user_guide.html
#     - Pytorch tutorials available online: https://pytorch.org/tutorials/
#     - Nice visuals on CNN - https://github.com/vdumoulin/conv_arithmetic

# %% [markdown]
# ### Grading Percentage
#
# - Project 50\% (4 in total)
#     - 3 Mini projects 10\% each - 1 people
#     - 1 Mega project 20\% - groups of 1-3 people
# - Labs 5\%
# - Quiz 10\%
# - Final Exam 20\%
# - Midterm Exam 15\%
# - Bonus 5\%
#
# Note: follows gaussian distribution
#
# Note2: I provide special bonus points for those who can identify bugs in my code, or mathematical errors in my formulas. (I don't give points to typos but let me know as well!) This is the incentive for those who carefully read my lecture notes.

# %% [markdown]
# ### Course Outline
#
# **Bootcamp** (2 weeks before the course starts)
# - 0.1 Intro to Python
# - 0.2 Numpy
# - 0.3 Pandas
# - 0.4 Matplotlib
# - 0.5 Sklearn pipelines
#
# **Course starts** (15 weeks in total including midterm and final)
# - W1.1 Linear regression and regularization
# - W1.2 Logistic regression
# - W2.1 Naive Gaussian
# - W2.2 Support Vector Machine
# - W3.1 *Project Day (Must come to class; discuss personally)*
# - W3.2 **1st Mini project presentation**
# - W4.1 Neural Network Basics
# - W4.2 PyTorch Basics
# - W5.1 Convolutional Neural Network
# - W5.2 Generative Adversarial Network
# - W6.1 Variational Autoencoders
# - W6.2 Transfer Learning
# - W7.1 *Project Day (Must come to class; discuss personally)*
# - W7.2 **Midterm exam**
# - W8.1 **2nd Mini project presentation**
# - W8.2 **Special Talk by my lab student (AIT Brain Lab): Transfer Learning, Natural Language Processing/Text Mining, Transformers, GANs, Autoencoders, Blind Source Separation**
# - W9.1 Natural Language Processing 1
# - W9.2 Natural Language Processing 2
# - W10.1 Natural Language Processing 3
# - W10.2 *Project Day (Must come to class; discuss personally)*
# - W11.1 **3rd Mini project presentation**
# - W11.2 Audio Processing 1
# - W12.1 Audio Processing 2
# - W12.2 *Project Day (Must come to class; discuss personally)* (p)
# - W13.1 *Project Day (Must come to class; discuss personally)*
# - W13.2 **Mega project progress presentation** (pr)
# - W14.1 *Project Day (Must come to class; discuss personally)*
# - W14.2 *Project Day (Must come to class; discuss personally)*
# - W15 **Final Exam**
# - W16 **Mega project presentation** (week after final exam) (f)
#
# *Notes*
#
# Note 1: (p) stands for proposal submission, (pr) for progress report, (f) for final report.  All must be submitted on the day of presentation.
#
# Note 2: I may open an Q&A session day where I shall recap things we have learned so far, but in a much slower fashion.  This is for those who have difficulty following mathematics or python.  The special Q&A session shall be announced later.
#
# Note 3: There are many other topics I did not cover, such as K-means, PCA, GMM.  You can find my tutorials on my last year videos if you want to self-study.  THEY ARE VERY IMPORTANT ACTUALLY!

# %% [markdown]
# ### Midterm and Final
#
# * Mid-term and final will be **open book, open internet**, practical exams
# * No makeup exams are allowed

# %% [markdown]
# ### Labs
#
# * Every class will be a mandatory lab, where you need to submit them in the form of Python Notebook in Google Classroom by the **class hour**.  You will be given roughly 1 and half hour to complete the lab.
#
# * Labs will be written as "Tasks" in the lecture notes, or else, it shall be specified by the instructor.
#
# * It is highly recommended to read the materials before you come to class, or you will be very anxious about all these flying labs and you won't learn much.

# %% [markdown]
# ### Quiz
#
# * TA will carry 5 quizzes in the entire semester in the Google classroom.  The quizzes will be conducted using 15 minutes in the beginning of the class. TA has the privilege to make it a surprise quiz or informed quiz, in whatever way TA desires to.
# * If you miss the quiz, there is no make-up

# %% [markdown]
# ### Mini Project
#
# One of this course main goals is to prepare you to apply machine learning algorithms to real-world tasks, or to leave you well-qualified to start machine learning or AI research.
#
# A total of three mini projects are to make you prepared for the mega project.  This will be done solely by you alone to ensure you develop essential skills reuqired to complete the mega project.
#
# #### Topics
#
# Your first task is to pick a project topic. To pick a project topic for a mini-project, you are required to read **at least 3 papers** of the recent 3-5 years. It can be useful to look up existing research on relevant topics by searching related keywords on an academic search engine such as: http://scholar.google.com. Also, I have prepared a list of must read papers in "0 - Reading Roadmap" which should be a good start.
#
# Another important aspect of designing your project is to identify one or several **datasets** suitable for your topic of interest. If that data needs considerable pre-processing  to suit your task, or that you intend to collect the needed data yourself, keep in mind that this is only one part of the expected project work, but can often take considerable time. We still expect a solid methodology and discussion of results, so pace your project accordingly.
#
# #### Submission
#
# We’ll be using Google classroom for submission.  Deliverables include:
#
# - A github repository containing
#     - README file explaining the work
#     - PPT / Slides
#     - Jupyter Notebook
#     - Dataset (if too big, link to GDrive)
#
# #### Criteria
#
# Project will be evaluated based on:
#
# - **The technical quality of the work.** (I.e., Does the technical material make sense? Are the things tried reasonable? Are the proposed algorithms or applications clever and interesting? Do the authors convey novel insight about the problem and/or algorithms?)
#
# - **Significance**. (Did the authors choose an interesting or a “real" problem to work on, or only a small “toy" problem? Is this work likely to be useful and/or have impact?)
#
# - **The novelty of the work.** (Is this project applying a common technique to a well-studied problem, or is the problem or method relatively unexplored?)
#
# In order to highlight these components, it is important you present a solid discussion regarding the learnings from the development of your method, and summarizing how your work compares to existing approaches.  Last but not least, we tend to judge anything that is publishable or nearly to be a A project.
#
# #### Presentation
#
# You need to spend 5 minutes to present your project in front of the class and 2 more minutes for Q&A.  Make sure to cover:
#
# - Problem
# - Related Work (at least 3 papers)
# - Solution
#
# #### FAQs
#
# 1. Should project use only methods taught in classroom?
#
# No, we encourage you to read more recent papers and recent methods.  But make sure you always include some **baseline methods.**
#
# 2. Can I use libraries like sklearn or pyTorch or from scratch?
#
# Any libraries are fine but Python is a must.  For deep learning, we highly recommend you using pyTorch because I and the TAs ONLY know pyTorch.
#
# 3. Can I not use Github?
#
# No.  There is optional tool like bitbucket but we found that it is just too much hurdles for TAs and mentors to look at different places.
#
# 4. Is there any particular project we don't recommend?
#
# Yes, example projects such as those tutorials in Kaggle or medium.com will NOT be ok.  We judge for novelty, significance, and technicality, so usually those projects will not be sufficient.  Also, if you want to work on certain project, make sure you have enough domain knowledge.  For example, if you want to work on finance, make sure you know finance really well.

# %% [markdown]
# ### Mega Project
#
# Mega project assumes you to combine all your gained expertise to creatively create something.
#
# #### Topics
#
# **To pick a project topic for the mega-project, you are required to read at least 20 papers of the recent 3-5 years.**
#
# Most students do one of three kinds of projects:
#
# - **Application project.** This is by far the most common: Pick an application that interests you, and explore how best to apply learning algorithms to solve it.  Of course, you will then need to read 20 papers, mostly application oriented.
#
# - **Algorithmic project**. Pick a problem or family of problems, and develop a new learning algorithm, or a novel variant of an existing algorithm, to solve it.
#
# - **Theoretical project.** Prove some interesting/non-trivial properties of a new or an existing learning algorithm. (This is often quite difficult, and so very few, if any, projects will be purely theoretical.)
#
# Some projects will also combine elements of applications, algorithms and theory.
#
# Many fantastic class projects come from students picking either an application area that they're interested in, or picking some subfield of machine learning that they want to explore more. So, pick something that you can get **excited and passionate about!** Be brave rather than timid, and do feel free to propose ambitious things that you're excited about. (Just be sure to read a lot of papers, and consult your mentor if you're uncertain how to best get started.)
#
# **A very good project (grade A) will be a publishable or nearly-publishable piece of work**. Each year, some number of students continue working on their projects, submitting their work to a conferences or journals. Thus, for related work, you might also look at some recent machine learning research papers. Two of the main machine learning conferences are ICML and NIPS. You can find papers from the recent ICML https://icml.cc/Conferences/2019/Schedule and NeurIPS conference https://neurips.cc/Conferences/2019/Schedule.
#
# Once you have identified a topic of interest, it can be useful to look up existing research on relevant topics by searching related keywords on an academic search engine such as: http://scholar.google.com.
#
# Another important aspect of designing your project is to identify one or several **datasets** suitable for your topic of interest. If that data needs considerable pre-processing  to suit your task, or that you intend to collect the needed data yourself, keep in mind that this is only one part of the expected project work, but can often take considerable time. We still expect a solid methodology and discussion of results, so pace your project accordingly.
#
# Notes on a few specific types of projects:
#
# - **Deep learning projects**: Since our course discusses many other concepts besides deep learning, we ask that if you decide to work on a deep learning project, please make sure that you use other material you learned in the class as well. For example, you might set up logistic regression and SVM baselines, or do some data analysis using the unsupervised methods covered in class. We may grade these projects using different criteria to make sure that grading is fair for students who have not had exposure to DL before. Finally, training deep learning models can be very time consuming, so make sure you have the necessary computing resources.
#
# - **Preprocessed datasets**: While we don't want you to have to spend much time collecting raw data, the process of inspecting and visualizing the data, trying out different types of preprocessing, and doing error analysis is often an important part of machine learning. Hence if you choose to use preprepared datasets (e.g. from Kaggle, the UCI machine learning repository, etc.) we encourage you to do some data exploration and analysis to get familiar with the problem.
#
# - **Replicating results**: Replicating the results in a paper can be a good way to learn. However, we ask that instead of just replicating a paper, also try using the technique on another application, or do some analysis of how each component of the model contributes to final performance.
#
# #### Project Parts: Proposal, Progress Report, and Final Report Presentation
#
# This section contains the detailed instructions for the different parts of your project.  Make sure you plan ahead!
#
# **Group number**: 1-3 people.  No more than 3 people will be allowed, except for cases of uneven division.  No special treatment for lone wolves as well.
#
# **Submission**: We’ll be using Google classroom for submission of all three parts of the final project. You should submit as a group: that is, for each part, please make one submission for your entire project group.  Don't forget to write your team member names.
#
# **Criteria**
#
# The final report will be the majority of the grade. Projects will be evaluated based on:
#
# - **The technical quality of the work.** (I.e., Does the technical material make sense? Are the things tried reasonable? Are the proposed algorithms or applications clever and interesting? Do the authors convey novel insight about the problem and/or algorithms?)
#
# - **Significance**. (Did the authors choose an interesting or a “real" problem to work on, or only a small “toy" problem? Is this work likely to be useful and/or have impact?)
#
# - **The novelty of the work.** (Is this project applying a common technique to a well-studied problem, or is the problem or method relatively unexplored?)
#
# In order to highlight these components, it is important you present a solid discussion regarding the learnings from the development of your method, and summarizing how your work compares to existing approaches.  Last but not least, we tend to judge anything that is publishable or nearly to be a A project.
#
# **Part 1: Proposal report**
#
# In the project proposal, you'll pick a project idea to work on early and receive feedback from the mentor.  Make sure you read at least 20 papers.
#
# In the proposal, below your project title, include the project category. The category can be one of:
#
# - Athletics & Sensing Devices
# - Audio & Music
# - Computer Vision
# - Finance & Commerce
# - General Machine Learning
# - Life Sciences
# - Natural Language Processing
# - Neuroscience
# - Physical Sciences
# - Theory & Reinforcement Learning
#
# *Format* - Paper writing in **IEEE format**.  You MUST use latex format (.tex) and submit both PDF and latex.  Format can be downloaded here (https://journals.ieeeauthorcenter.ieee.org/create-your-ieee-journal-article/authoring-tools-and-templates/tools-for-ieee-authors/ieee-article-templates/ - choose journal)
#
# *Length* - Typically, the proposal will include the Introduction and Related Work, and the Method section, so roughly 2 pages will suffice, excluding references.
#
# *Github* - Initialize a git repository containing the proposal, and add all team members in.  Grading shall be judged based on the weight of committments by each member.
#
# Your project proposal should include the following information:
# - Motivation: What problem are you tackling? Is this an application or a theoretical result?
# - Related work: What are the gap of the current work?
# - Method: What machine learning techniques are you planning to apply or improve upon?
# - Intended experiments: What experiments are you planning to run? How do you plan to evaluate your machine learning algorithm?
#
# *Grading* - The project proposal is mainly intended to make sure you decide on a project topic and get feedback early. As long as your proposal follows the instructions above and the project seems to have been thought out with a reasonable plan, you should do well on the proposal.
#
# *Submission*
#
# We’ll be using Google classroom for submission.  Deliverables include:
#
# - Proposal
#     - Github repo link containing report in LaTeX and PDF format, and README file.
#
# **Part 2: Progress Report**
#
# The progress report will help you make sure you're on track, and should describe what you've accomplished so far, and very briefly say what else you plan to do. You should write it as if it's an “early draft" of what will turn into your final project. You can write it as if you're writing the first few pages of your final project report, so that you can re-use most of the progress report text in your final report. Please write the milestone (and final report) keeping in mind that the intended audience are the instructors and the mentors. Thus, for example, **you should not spend two pages explaining what logistic regression is**. Your milestone should include the full names of all your team members and state the full title of your project. Note: We will expect your final writeup to be on the same topic as your progress report.
#
# *Length* - Typically, the proposal will include the Introduction and Related Work, and the Method section but with added details, so roughly 3 pages will suffice, excluding references.
#
# *Github* - Commit things to the repository.  Similarly, grading shall be judged based on the weight of committments by each member.
#
# Similar to the proposal, it should include (revised version):
# - Motivation: What problem are you tackling? Is this an application or a theoretical result?
# - Related work: What are the gap of the current work?
# - Method: What machine learning techniques are you planning to apply or improve upon?
# - Preliminary experiments: Describe the experiments that you've run, the outcomes, and any error analysis that you've done. You should have tried at least one baseline.
# - Next steps: Given your preliminary results, what are the next steps that you're considering?
#
# *Grading* - The progress report is mainly intended to make sure you are making a reasonable progress and get feedback early. As long as your progress report follows the instructions above and you seem to have tested any assumptions which might prevent your team from completing the project, you should do well on the progress.
#
# *Submission*
#
# We’ll be using Google classroom for submission.  Deliverables include:
#
# - Progress report
#     - Github repo link containining report in LaTeX and PDF format, jupyter notebooks/python code, dataset link, and the slides
#
# **Part 3: Final Report and Presentation**
#
# *Length* - Final report writeups can be at most 5 pages long (including appendices and figures). We will allow for extra pages containing only references.
#
# *Github* - Commit all the code and your additions to the repository.  Similarly, grading shall be judged based on the weight of committments by each member.
#
# Similar to the proposal, it should include (revised version):
# - Motivation: What problem are you tackling? Is this an application or a theoretical result?
# - Related work: What are the gap of the current work?
# - Method: What machine learning techniques are you planning to apply or improve upon?
# - Experiments: Describe the experiments that you've run, the outcomes, and any error analysis that you've done. You should have tried at least one baseline.   This should be more rigorous than your progress report.
# - Discussion: Interpret your results.  Why do you think the results are like that?  What would you do differently?  Do you get what you want?  How far/close to your related are you?
# - Future work: What would be a promising future work you would do, following this work?
#
# *Grading* - The final report will be judged based off of the clarity of the report, the relevance of the project to topics taught in this course, the novelty of the problem, and the technical quality and significance of the work.
#
# *Submission*
#
# We’ll be using Google classroom for submission.  Deliverables include:
#
# - Final report
#     - Github repo link containining report in LaTeX and PDF format, jupyter notebooks/python code, dataset link, and the slides
#
# *Presentation*
#
# You need to spend 15 minutes to present your project in front of the class and 5 more minutes for Q&A.  Make sure to cover:
#
# - Motivation
# - Related Work
# - Method
# - Experiments
# - Discussion
# - Future Work
#
# ### FAQs
#
# 1. Should project use only methods taught in classroom?
#
# No, we encourage you to read more recent papers and recent methods.  But make sure you always include some **baseline methods.**
#
# 2. Can I use libraries like sklearn or pyTorch or from scratch?
#
# Any libraries are fine but Python is a must.  For deep learning, we highly recommend you using pyTorch because I and the mentors ONLY know pyTorch.
#
# 3. Can I not use Github?
#
# No.  There is optional tool like bitbucket but we found that it is just too much hurdles for TAs and mentors to look at different places.
#
# 4. Is there any particular project we don't recommend?
#
# Yes, example projects such as those tutorials in Kaggle or medium.com will NOT be ok.  We judge for novelty, significance, and technicality, so usually those projects will not be sufficient.  Also, if you want to work on certain project, make sure you have enough domain knowledge.  For example, if you want to work on finance, make sure you know finance really well.
