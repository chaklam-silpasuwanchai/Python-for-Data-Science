# %% [markdown]
# # Programming for Data Science and Artificial Intelligence
#
# ## 0 Course Introduction

# %% [markdown]
# * My name is **Chaklam**.  Welcome you all!
#
# * My email - **chaklam@ait.asia**
#
# * All materials can be found on my **Github - https://github.com/chaklam-silpasuwanchai/**.  If you forget, you can also get the link from http://chaklam.com
#
# * Our TAs, **Mr. Akraradet** (Jo) - st121413@ait.asia
#
# * Google classroom code - announce in class
#
# ### Setting up your Python and Jupyter
#
# * Setup python and jupyter - **Prerequisites/0 - Installation.md**
#
# * CSIM resources - https://puffer.cs.ait.ac.th
#
# ### Pre-requisites
#
# * Have some experience in **programming**
#
# * Study some **coursera/udemy course** in Python a bit.
#
# * Understand basic **math notations**, if not, read **Prerequisites/0 - Course Notations.ipynb**
#
# * Require **great amount** of **self-study hours**, especially if you are weak in programming/math
#
#
# ### Expectation
#
# * Work hard!!
#
# ### What you will learn
#
# - Understand Python, Numpy, Pandas, Matplotlib, Sklearn (bootcamp)
#
# - Coding classic machine learning algorithms from scratch
#
# - Coding deep learning using PyTorch (to prepare you for NLP and Recent Trends for ML)
#
# ### What you will NOT learn
#
# - Not focus on software engineering side of machine learning / deep learning.
#
# ### Resources
#
# * Reference books:
#     - [GERON] Geron, A. **Hands-On Machine Learning with Scikit-Learn and TensorFlow: Concepts, Tools, and Techniques to Build Intelligent Systems**, 2019 (2nd edition) (https://github.com/ageron/handson-ml2)
#     - [VANDER] VanderPlas, J. **Python Data Science Handbook: Essential Tools for Working with Data**, 2016 (1st edition) (https://jakevdp.github.io/PythonDataScienceHandbook/)
#     - [HASTIE] Hastie, T., Tibshirani, R., and Friedman, J. **The Elements of Statistical Learning: Data Mining, Inference, and Prediction**, 2016 (2nd edition) (https://web.stanford.edu/~hastie/)
#     - [WEIDMAN] Weidman, S. **Deep Learning from Scratch: Building with Python from First Principles**, 2019 (1st edition) (https://github.com/SethHWeidman/DLFS_code)
#     - [CHARU] Charu, C. **Neural Networks and Deep Learning: A Textbook**, 2018 (1st edition)
#     - [Deisenroth] Deisenroth, M.P., Faisal A.A., Ong, C.S., **Mathematics for Machine Learning**, 2020 (1st edition) (https://mml-book.github.io/book/mml-book.pdf)
#
# * Online resources:
#     - Python tutorials available online: https://docs.python.org/3/tutorial/
#     - Jupyter notebook tutorials available online: https://ipython.org/documentation.html
#     - Numpy tutorials available online:https://numpy.org/doc/stable/
#     - Pandas tutorials available online: https://pandas.pydata.org/docs/
#     - Nltk tutorials available online: https://www.nltk.org
#     - Matplotlib tutorials available online: https://matplotlib.org/contents.html
#     - Scikit-learn tutorials available online: https://scikit-learn.org/stable/user_guide.html
#     - Pytorch tutorials available online: https://pytorch.org/tutorials/
#     - Nice visuals on CNN - https://github.com/vdumoulin/conv_arithmetic

# %% [markdown]
# ### Grading Percentage
#
# - Quiz  10\%
# - Project 35\%
# - Midterm Exam 20\%
# - Final Exam 35\%
#
# Note: follows gaussian distribution

# %% [markdown]
# ### Course Outline
#
# **Bootcamp** (2 weeks before the course starts)
# - 0.0 Docker + Github + Installation (by TA) (Friday before the two weeks bootcamp)
# - 0.1 Intro to Python
# - 0.2 Numpy
# - 0.3 Pandas
# - 0.4 Matplotlib
# - 0.5 Sklearn
# - 0.6 Django + Model Deployment (by TA)
#
# **Course starts** (15 weeks in total including midterm; each week has 2 labs, each lab takes 3 hours.)
# - W1.1 Linear regression
# - W1.2 Binary Logistic Regression
# - W2.1 Multinomial Logistic Regression (Quiz 1:  Practical and Theory-Linear Regression)
# - W2.2 Gaussian Naive Baye
# - W3.1 Multinomial Naive Baye
# - W3.2 SVM I (Quiz 2:  Practical and Theory: Logistic Regression and Naive Baye)
# - W4.1 SVM II
# - W4.2 K-Nearest Neighbors
# - W5.1 Decision Tree (Quiz 3:  Practical and Theory: SVM and KNN)
# - W5.2 Random Forest
# - W6.1 AdaBoost
# - W6.2 Gradient Boosting  (Quiz 4:  Theory: Supervised Learning)
# - W7.1 K-Means
# - W7.2 **Midterm exam**
# - W8.1 Gaussian Mixture
# - W8.2 Principal Component Analysis
# - W9.1 **Project tips**
# - W9.2 PyTorch Linear Regression
# - W10.1 PyTorch Logistic Regression
# - W10.2 PyTorch Convolutional Neural Network  (Quiz 5:  Practical and Theory: PyTorch)
# - W11.1 NLP + TorchText
# - W11.2 NLP + TorchText + Embedding
# - W12.1 NLP + TorchText + Embedding + BiLSTM
# - W12.2 **Project progress**
# - W13.1 NLP + TorchText + CNN
# - W13.2 Historical Stock Price Prediction  (Quiz 6: Practical and Theory: CNN and RNN)
# - W14.1 Historical Stock Price + Sentiment Prediction
# - W14.2 Signal Processing (by TA)
# - W15.1 Signal Processing II (EEG as Case Study) (by TA)
# - W15.2 **Final project presentation**
# - W16 **Final Exam**

# %% [markdown]
# ### Midterm and Final
#
# * Mid-term and final will be **open book, open internet**, practical exams
# * No makeup exams are allowed

# %% [markdown]
# ### Final Project
#
# #### Scope
#
# The scope focuses on the **pipeline of data science** - exploring, preprocessing, splitting, training, validating. Accuracy may not be the sole focus, but usually a good pipeline will provide relatively decent performance.
#
# #### Topics
#
# Four possible topics:
#
# - Select one **present** challenge in Kaggle/AICrowd and completed it
#
# - Select one **academic paper** and implement it.  Make sure there is no code available in github.  The paper should also be more complicated than simple CNN or LSTM.
#
# - Obtain an **unique dataset** from your previous company/contacts, and perform modeling.
#
# - Develop a **novel AI-based application**
#
#
# #### Deliverables
#
# Deliverables will be focused on boosting your resume, toward achieving a good career.
#
# - Your python (.py)/notebook (.ipynb) file
#
# - A medium article that you are proud of
#
# - A github link, together with a useful README
#
# - A presentation (PPT/PDF)
#
# #### Group number
#
# 3-4 people.  Group leader will be provided in a google sheet - https://docs.google.com/spreadsheets/d/1vRaDaAhkhGsmetLwA_YBY6I5XbFQ-Tp5Pl8NxJ9y9Es/edit#gid=0
#
#
# #### Criteria
#
# START EARLY!
#
# Projects will be evaluated based on:
#
# - **A**: Valid pipeline, carried out experiments, technically satisfying, shows great understanding
# - **B**: Valid pipeline, carried out experiments
# - **C**: Poorly executed work in general
# - **D**: Couple of hours work / last minute work
# - **F**: Directly copy from internet, e.g., kaggle, github
#
# #### Presentation
#
# 15 minutes to present your project.  Make sure to cover:
#
# - Motivation (what is the project about)
# - Experiments (describe what you compare, how you measure)
#   - we want to see you use some experiment tool
# - Discussion  (did you get what you expect, what you have learn)
# - Future Work  (what can you do better)
# - Demo  (show some demo)
