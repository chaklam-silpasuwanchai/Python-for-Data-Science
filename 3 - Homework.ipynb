# %% [markdown]
# # Exercise

# %% [markdown]
# ## Apple Stock

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

apple = pd.read_csv("resources/appl_1980_2014.csv")
apple.head()
# Out:
#          Date   Open   High    Low  Close    Volume  Adj Close
# 0  2014-07-08  96.27  96.80  93.92  95.35  65130000      95.35
# 1  2014-07-07  94.14  95.99  94.10  95.97  56305400      95.97
# 2  2014-07-03  93.67  94.10  93.20  94.03  22891800      94.03
# 3  2014-07-02  93.87  94.06  93.09  93.48  28420900      93.48
# 4  2014-07-01  93.52  94.07  93.13  93.52  38170200      93.52

# %% [markdown]
# # #1.1

# %%
#Transform date coumn to datetime type
#then set the date column as index
#and filter only with year not less than 1987

# %% [markdown]
# # #1.2

# %%
#use index.is_unique to check whether all index are unique

# %% [markdown]
# # #1.3

# %%
#Sort the index in a ascending order (oldest date first) - use sort_index

# %% [markdown]
# # #1.4

# %%
#I want to know how apple does on end of every month, thus
#Get the mean value for each columns, resample at last buiness day of each month (i.e., BM)

# %% [markdown]
# # #1.5

# %%
#BTW, how many months do we have in our data?

# %% [markdown]
# # #1.6

# %%
#Compare this year and last year High column.  Explain what do you see
#you may use .plot() for easy visualization

# %% [markdown]
# # #1.7

# %%
#resample to 3 years and run .plot

# %% [markdown]
# # #1.8

# %%
#perform a rolling mean (moving average) of Close with window size of 100 days

# %% [markdown]
# # #1.9

# %%
from pandas_datareader import data

microsoft = data.DataReader('MSFT', start='1987', end='2014',
                      data_source='yahoo')

microsoft.head()

#let's compare them based on return rate based on the first day of IPO
#i.e., close price / close price [0], where [0] is the first close price
#to make things even more interesting, we shall look at the performance
#from year 2000 onwards....
# Out:
# /Users/chaklam/DSAI/Environments/teaching_env/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal
#                 High       Low      Open     Close      Volume  Adj Close
# Date
# 1986-12-31  0.170139  0.165799  0.165799  0.167535  23356800.0   0.107193
# 1987-01-02  0.169271  0.164931  0.167535  0.165799  12643200.0   0.106082
# 1987-01-05  0.177083  0.164931  0.165799  0.175347  48499200.0   0.112191
# 1987-01-06  0.178819  0.174479  0.175347  0.177951  40032000.0   0.113857
# 1987-01-07  0.187500  0.177951  0.177951  0.187500  60998400.0   0.119967

# %% [markdown]
# ## Euro Cup

# %%
euro = pd.read_csv("resources/euro2012.csv")
euro.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %% [markdown]
# # #2.1

# %%
#let's check which country get the most red cards and yellow cards

# %% [markdown]
# # #2.2

# %%
#check which team score more than 6 goals

# %% [markdown]
# # #2.3

# %%
#select team starting with 'C'

# %% [markdown]
# # #2.4

# %%
#select all columns except the last 3

# %% [markdown]
# # #2.5

# %%
#create new column luck_index which is based on Hit Woodwork.  
#pd.cut to create three bins of luck index
#give labels as High, Medium, Low

# %% [markdown]
# # #2.6

# %%
#create new column "always_lose_goals" which has values of True or False
#based on clean sheets, if clean sheets is 0, then is True, otherwise False

# %% [markdown]
# # #2.7

# %%
#let's find out whether our luck_index works
#group by luck_index, find the mean of goals and % Goals-to-shots

# %% [markdown]
# # Solution

# %% [markdown]
# # #1.1

# %%
apple.Date = pd.to_datetime(apple.Date)
apple = apple[apple['Date'].dt.year > 1986]

#FYI: pd.Series._accessors  can show you what are all possible getters

apple = apple.set_index('Date')
apple.head(-5)
# Out:
#              Open   High    Low  Close     Volume  Adj Close
# Date
# 2014-07-08  96.27  96.80  93.92  95.35   65130000      95.35
# 2014-07-07  94.14  95.99  94.10  95.97   56305400      95.97
# 2014-07-03  93.67  94.10  93.20  94.03   22891800      94.03
# 2014-07-02  93.87  94.06  93.09  93.48   28420900      93.48
# 2014-07-01  93.52  94.07  93.13  93.52   38170200      93.52
# ...           ...    ...    ...    ...        ...        ...
# 1987-01-15  48.25  51.37  48.00  49.87  136640000       0.78
# 1987-01-14  44.63  48.25  44.50  48.13  126000000       0.75
# 1987-01-13  45.12  45.38  44.63  44.63   52931200       0.70
# 1987-01-12  45.50  45.75  44.75  45.50   58240000       0.71
# 1987-01-09  44.75  45.75  44.37  45.38   59920000       0.71
#
# [6931 rows x 6 columns]

# %% [markdown]
# # #1.2

# %%
apple.index.is_unique
# Out:
# True

# %% [markdown]
# # #1.3

# %%
#3
apple.sort_index(ascending = True, inplace=True)

# %% [markdown]
# # #1.4

# %%
apple_month = apple.resample('BM').mean()
apple_month
# Out:
#                   Open        High         Low       Close        Volume  \
# Date
# 1987-01-30   48.119048   49.666667   47.165714   48.732857  9.843947e+07
# 1987-02-27   59.625789   61.262632   58.513158   60.382632  8.705495e+07
# 1987-03-31   66.363636   67.505909   65.135909   66.221818  6.771953e+07
# 1987-04-30   71.565238   73.451905   70.565714   72.196667  8.110907e+07
# 1987-05-29   77.750000   78.906500   76.756500   77.818500  4.798696e+07
# ...                ...         ...         ...         ...           ...
# 2014-03-31  533.593333  536.453810  530.070952  533.214286  5.954403e+07
# 2014-04-30  540.081905  544.349048  536.262381  541.074286  7.660787e+07
# 2014-05-30  601.301905  606.372857  598.332857  603.195714  6.828177e+07
# 2014-06-30  222.360000  224.084286  220.735714  222.658095  5.745506e+07
# 2014-07-31   94.294000   95.004000   93.488000   94.470000  4.218366e+07
#
#             Adj Close
# Date
# 1987-01-30   0.759524
# 1987-02-27   0.940000
# ...

# %% [markdown]
# # #1.5

# %%
len(apple_month.index)
# Out:
# 331

# %% [markdown]
# # #1.6

# %%
apple_high = apple['High']
apple_high_last_year =apple_high.shift(365)
apple_high.plot(style=['-'])
apple_high_last_year.plot(style=[':'])
diff = apple_high - apple_high_last_year
diff.plot(style=["--"])

#seems like we got lots of ups, but only in year 2002 that we see the dip
#likely because in 2000, apple overperform a bit

# %% [markdown]
# # #1.7

# %%
apple_high = apple['High'].resample('5Y').mean()
apple_high.plot(style=['--'], xticks=apple_high.index)

# %% [markdown]
# # #1.8

# %%
apple_close = apple['Close']
apple_close.rolling(window=200).mean().plot(style='-')
apple_close.plot(style='--', figsize=(10, 7))
plt.title("Whatever title you like")
plt.ylabel('Close Price', fontsize=14)
# Out:
# Text(0, 0.5, 'Close Price')

# %% [markdown]
# # #1.9

# %%
import datetime

microsoft = data.DataReader('MSFT', start='1987', end='2014',
                      data_source='yahoo')

microsoft_close = microsoft['Close']

apple_close = apple_close['2000':]
microsoft_close = microsoft_close['2000':]

apple_return = apple_close.apply(lambda x: x / apple_close[0])
microsoft_return = microsoft_close.apply(lambda x: x / microsoft_close[0])

apple_return.plot(style=["g--"], figsize=(10, 7))
microsoft_return.plot(style=["r:"])

# %% [markdown]
# # #2.1

# %%
discipline = euro[['Team', 'Yellow Cards', 'Red Cards']]
discipline.sort_values(['Red Cards', 'Yellow Cards'], ascending = False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# # #2.2

# %%
euro[euro.Goals > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# # #2.3

# %%
euro[euro.Team.str.startswith('C')]
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 0                     0  ...          13                 81.3%         41
# 1                     0  ...           9                 60.1%         53
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 0             62         2             9          0        9         9
# 1             73         8             7          0       11        11
#
#    Players Used
# 0            16
# 1            19
#
# ...

# %% [markdown]
# # #2.4

# %%
#every row, #column until the last three
euro.iloc[:, : - 3 ]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# # #2.5

# %%
euro['luck_index'] = pd.cut(euro['Hit Woodwork'], bins= 3, labels=["High", "Medium", "Low"])
euro
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# # #2.6

# %%
def no_clean_sheets(x):
    if x == 0:
        return True
    else:
        return False

euro['alway_lose_goals'] = euro['Clean Sheets'].apply(no_clean_sheets)
euro
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# # #2.7

# %%
print("Type: ", euro['% Goals-to-shots'].dtypes)
#seems like the type is object!

#let's convert it to float
def converter(x):
    return float(x.strip('%'))/100

euro['% Goals-to-shots'] = euro['% Goals-to-shots'].apply(converter)

print("Should be float now: ", euro['% Goals-to-shots'].dtypes)

euro.groupby(['luck_index']).agg({'Goals':'mean', '% Goals-to-shots':'mean'})
# Out:
# Type:  object
# Should be float now:  float64
#                Goals  % Goals-to-shots
# luck_index
# High        4.642857          0.117071
# Medium      5.000000          0.138000
# Low         6.000000          0.093000
